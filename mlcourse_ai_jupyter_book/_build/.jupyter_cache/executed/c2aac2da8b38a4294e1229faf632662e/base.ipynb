# %%
# some necessary imports
from pathlib import Path
import pandas as pd
DATA_PATH = Path("../../")

print(list(DATA_PATH.glob('*')))
# Out:
# [PosixPath('../../0'), PosixPath('../../_static'), PosixPath('../../T'), PosixPath('../../data'), PosixPath('../../tmp'), PosixPath('../../C')]

# %%
#train_df = pd.read_csv(DATA_PATH / "athlete_events.csv.zip")
#train_df.head()-->
