# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course
# Author: Arina Lopukhova (@erynn). Edited by [Yury Kashnitskiy](https://yorko.github.io) (@yorko) and Vadim Shestopalov (@vchulski). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# # <center>Assignment #1. Fall 2019
# ## <center>Exploratory data analysis of Olympic games with Pandas
#
# <img src='../../img/olympic_logo.png' width=50%>

# %% [markdown]
# Prior to working on the assignment, you'd better check out the corresponding course material:
#  - [Exploratory data analysis with Pandas](https://nbviewer.jupyter.org/github/Yorko/mlcourse_open/blob/master/jupyter_english/topic01_pandas_data_analysis/topic1_pandas_data_analysis.ipynb?flush_cache=true), the same as an interactive web-based [Kaggle Kernel](https://www.kaggle.com/kashnitsky/topic-1-exploratory-data-analysis-with-pandas)
#  - first lectures in mlcourse.ai [YouTube playlist ](https://www.youtube.com/watch?v=QKTuw4PNOsU&list=PLVlY_7IJCMJeRfZ68eVfEcu-UcN9BbwiX)
#  - you can also practice with demo assignments, which are simpler and already shared with solutions: [A1 demo](https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset), [solution](https://www.kaggle.com/kashnitsky/a1-demo-pandas-and-uci-adult-dataset-solution)
#
# ### Your task is to:
#  1. write code and perform computations in the cells below
#  2. choose answers in the [webform](https://docs.google.com/forms/d/1JxhQ9Bg4OpM3E5N47ZuRbILgDuMRbvEnUbDMZK8L-NU). Solutions will be shared only with those who've filled in this form
#  3. submit answers with some email and **remember it**! This will be your ID during the course. Specify your real full name in the form as well (no nicks allowed in the final top-100 [rating](https://mlcourse.ai/rating)). If in doubt, you can re-submit the form till the deadline for A1, no problem, but stick to only one email.
#
# ### <center> Deadline for A1: 2019 September 15, 20:59 GMT (London time)
#
# You'll get up to 10 credits for this assignment.
#
# ### How to get help
# In [ODS Slack](https://opendatascience.slack.com) (if you still don't have access, fill in the [form](https://docs.google.com/forms/d/10HAN5huM996snUKjsNYyT_oOlm2uOsTKulKurb3oiNM/) mentioned on the mlcourse.ai main page), we have a channel **#mlcourse_ai_news** with announcements from the course team.
# You can discuss the course content freely in the **#mlcourse_ai** channel (we still have a huge Russian-speaking group, they have a separate channel **#mlcourse_ai_rus**).
#
# Here's how you reply in a thread (press this dialog icon to drill down into a thread):
#
# <img src="../../img/start_a_thread.png" />
#
# Please stick to special threads *a1_q1-5_fall2019* and *a1_q6-10_fall2019* in **#mlcourse_ai_news** for your questions on A1. Help each other without sharing correct code and answers. Our TA **Vadim @vchulski** is there to help (only in the mentioned thread, do not write to him directly).
#
# Lastly, you can save useful messages by pinning them, further you can find pinned items on the top, just below the channel name:
#
# <img src="../../img/pinned_item.png" />
#
# ### Assignment
# __There are ten questions about 120 years of Olympic history in this task. Your task is to fill in the missing Python code and choose answers in [this web-form](https://docs.google.com/forms/d/1JxhQ9Bg4OpM3E5N47ZuRbILgDuMRbvEnUbDMZK8L-NU).__

# %% [markdown]
# Download the file `athlete_events.csv` from [here](https://drive.google.com/file/d/1f5v6Z2ayc7h698FG_98wP5x1Y2zZQeox/view?usp=sharing) (scraped by [rgriffin](https://www.randigriffin.com/) from www.sports-reference.com). The dataset has the following features:
#
# - __ID__ - Unique number for each athlete
# - __Name__ - Athlete's name
# - __Sex__ - M or F
# - __Age__ - Integer
# - __Height__ - In centimeters
# - __Weight__ - In kilograms
# - __Team__ - Team name
# - __NOC__ - National Olympic Committee 3-letter code
# - __Games__ - Year and season
# - __Year__ - Integer
# - __Season__ - Summer or Winter
# - __City__ - Host city
# - __Sport__ - Sport
# - __Event__ - Event
# - __Medal__ - Gold, Silver, Bronze, or NA

# %%
import pandas as pd

# %%
# Change the path to the dataset file if needed. 
PATH = '../../data/athlete_events.csv'

# %%
data = pd.read_csv('../../data/athlete_events.csv')
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
# ID        271116 non-null int64
# Name      271116 non-null object
# Sex       271116 non-null object
# Age       261642 non-null float64
# Height    210945 non-null float64
# Weight    208241 non-null float64
# Team      271116 non-null object
# NOC       271116 non-null object
# Games     271116 non-null object
# Year      271116 non-null int64
# Season    271116 non-null object
# City      271116 non-null object
# Sport     271116 non-null object
# Event     271116 non-null object
# Medal     39783 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %% [markdown]
# __1. How old were the youngest male and female participants of the 1992 Olympics?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 16 and 15
# - 14 and 13
# - 13 and 11
# - 11 and 12 [+]

# %%
# You code here
data['Age'][(data['Year']==1992) & (data['Sex']=='M')].min()
# Out:
# 11.0

# %%
data[(data['Year']==1992)].sort_values(by='Age')
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 73461    37333  Carlos Bienvenido Front Barrera   M  11.0     NaN     NaN
# 120234   60854                       Judit Kiss   F  12.0   171.0    57.0
# 120233   60854                       Judit Kiss   F  12.0   171.0    57.0
# 80831    41040       Gina Elena Gogean (-Groza)   F  13.0   150.0    40.0
# 265499  132855          Wei Ling "Joscelin" Yeo   F  13.0   165.0    56.0
# 265498  132855          Wei Ling "Joscelin" Yeo   F  13.0   165.0    56.0
# 265497  132855          Wei Ling "Joscelin" Yeo   F  13.0   165.0    56.0
# 102920   52072                     Noriko Inada   F  13.0   167.0    60.0
# 265496  132855          Wei Ling "Joscelin" Yeo   F  13.0   165.0    56.0
# 102919   52072                     Noriko Inada   F  13.0   167.0    60.0
# 41953    21623               Clara Elena Ciocan   F  13.0   155.0    47.0
# 80830    41040       Gina Elena Gogean (-Groza)   F  13.0   150.0    40.0
# 80829    41040       Gina Elena Gogean (-Groza)   F  13.0   150.0    40.0
# 87962    44592                      Lyne Haddad   F  13.0   148.0    35.0
# 80827    41040       Gina Elena Gogean (-Groza)   F  13.0   150.0    40.0
# 73581    37398                       Fu Mingxia   F  13.0   160.0    48.0
# 52617    27017                   Cline Degrange   F  13.0   150.0    30.0
# 80826    41040       Gina Elena Gogean (-Groza)   F  13.0   150.0    40.0
# 265494  132855          Wei Ling "Joscelin" Yeo   F  13.0   165.0    56.0
# 265495  132855          Wei Ling "Joscelin" Yeo   F  13.0   165.0    56.0
# 80828    41040       Gina Elena Gogean (-Groza)   F  13.0   150.0    40.0
# 47557    24522         Krisztina Czak (-Horvth)   F  13.0   155.0    41.0
# 62787    32188                Rania Amr El-Wani   F  14.0   178.0    75.0
# 194235   97503                     Goran Puljko   M  14.0     NaN     NaN
# 131670   66264                     Robyn Lamsam   F  14.0     NaN     NaN
# 131668   66264                     Robyn Lamsam   F  14.0     NaN     NaN
# 104648   52963                    Kyoko Iwasaki   F  14.0   159.0    50.0
# 104649   52963                    Kyoko Iwasaki   F  14.0   159.0    50.0
# 104650   52963                    Kyoko Iwasaki   F  14.0   159.0    50.0
# 62788    32188                Rania Amr El-Wani   F  14.0   178.0    75.0
# ...        ...                              ...  ..   ...     ...     ...
# 62605    32069       Attaher Mohamed El-Mahjoub   M   NaN     NaN     NaN
# 78634    39912                   Addis Gezahegn   F   NaN   155.0    45.0
# 88366    44818               Zewdie Hailemariam   F   NaN   170.0    51.0
# 88367    44819                Tekle Hailemikael   M   NaN     NaN     NaN
# 90893    46046                     Khamis Harib   M   NaN   170.0    56.0
# 91759    46500                   Shemisu Hassan   M   NaN   168.0    56.0
# 97711    49456                Jean Alix Holmand   M   NaN     NaN     NaN
# 119297   60395                   Boureima Kimba   M   NaN     NaN     NaN
# 142611   71557    Christopher Paul "Chris" Lori   M   NaN     NaN     NaN
# 143695   72128               Stephen Lado Lugor   M   NaN   192.0    82.0
# 148865   74668                      Abdou Manzo   M   NaN     NaN     NaN
# 161226   80890           Ali Heidar Ali Mohamed   M   NaN   170.0    60.0
# 161890   81277                   Joseph Momanyi   M   NaN     NaN     NaN
# 162716   81706                          Moosaka   F   NaN     NaN     NaN
# 163135   81900                    Tigist Moreda   F   NaN   155.0    50.0
# 164820   82768               Faustin Mparabanyi   M   NaN     NaN     NaN
# 172461   86646              Emmanuel Nkurunziza   M   NaN     NaN     NaN
# 174861   87842            Donald Maisiba Obwoge   M   NaN     NaN     NaN
# 181423   91182             Raymond Anthony Papa   M   NaN     NaN     NaN
# 181424   91182             Raymond Anthony Papa   M   NaN     NaN     NaN
# 181425   91182             Raymond Anthony Papa   M   NaN     NaN     NaN
# 191526   96169               Silvestre Popoteur   M   NaN     NaN     NaN
# 215686  108288               Ildephonse Sehirwa   M   NaN     NaN     NaN
# 219027  110015                   Anita Shrestha   F   NaN     NaN     NaN
# 225740  113430          Moussa Awaleh Souleiman   M   NaN   174.0    50.0
# 225906  113518                        Oumou Sow   F   NaN     NaN     NaN
# 233224  116990     Oleg Gennadyevich Sveshnikov   M   NaN     NaN     NaN
# 235767  118212         Idrissou Souaibo Tamimou   M   NaN   175.0    70.0
# 235768  118212         Idrissou Souaibo Tamimou   M   NaN   175.0    70.0
# 238015  119360                   Daniel Tesfaye   M   NaN   173.0    65.0
#
#                         Team  NOC        Games  Year  Season         City  \
# 73461                  Spain  ESP  1992 Summer  1992  Summer    Barcelona
# 120234               Hungary  HUN  1992 Summer  1992  Summer    Barcelona
# 120233               Hungary  HUN  1992 Summer  1992  Summer    Barcelona
# 80831                Romania  ROU  1992 Summer  1992  Summer    Barcelona
# 265499             Singapore  SGP  1992 Summer  1992  Summer    Barcelona
# 265498             Singapore  SGP  1992 Summer  1992  Summer    Barcelona
# 265497             Singapore  SGP  1992 Summer  1992  Summer    Barcelona
# 102920                 Japan  JPN  1992 Summer  1992  Summer    Barcelona
# 265496             Singapore  SGP  1992 Summer  1992  Summer    Barcelona
# 102919                 Japan  JPN  1992 Summer  1992  Summer    Barcelona
# 41953                Romania  ROU  1992 Summer  1992  Summer    Barcelona
# 80830                Romania  ROU  1992 Summer  1992  Summer    Barcelona
# 80829                Romania  ROU  1992 Summer  1992  Summer    Barcelona
# 87962                 France  FRA  1992 Winter  1992  Winter  Albertville
# 80827                Romania  ROU  1992 Summer  1992  Summer    Barcelona
# 73581                  China  CHN  1992 Summer  1992  Summer    Barcelona
# 52617                 France  FRA  1992 Summer  1992  Summer    Barcelona
# 80826                Romania  ROU  1992 Summer  1992  Summer    Barcelona
# 265494             Singapore  SGP  1992 Summer  1992  Summer    Barcelona
# 265495             Singapore  SGP  1992 Summer  1992  Summer    Barcelona
# 80828                Romania  ROU  1992 Summer  1992  Summer    Barcelona
# 47557                Hungary  HUN  1992 Winter  1992  Winter  Albertville
# 62787                  Egypt  EGY  1992 Summer  1992  Summer    Barcelona
# 194235               Croatia  CRO  1992 Summer  1992  Summer    Barcelona
# 131670             Hong Kong  HKG  1992 Summer  1992  Summer    Barcelona
# 131668             Hong Kong  HKG  1992 Summer  1992  Summer    Barcelona
# 104648                 Japan  JPN  1992 Summer  1992  Summer    Barcelona
# 104649                 Japan  JPN  1992 Summer  1992  Summer    Barcelona
# 104650                 Japan  JPN  1992 Summer  1992  Summer    Barcelona
# 62788                  Egypt  EGY  1992 Summer  1992  Summer    Barcelona
# ...                      ...  ...          ...   ...     ...          ...
# 62605                  Libya  LBA  1992 Summer  1992  Summer    Barcelona
# 78634               Ethiopia  ETH  1992 Summer  1992  Summer    Barcelona
# 88366               Ethiopia  ETH  1992 Summer  1992  Summer    Barcelona
# 88367               Ethiopia  ETH  1992 Summer  1992  Summer    Barcelona
# 90893   United Arab Emirates  UAE  1992 Summer  1992  Summer    Barcelona
# 91759               Ethiopia  ETH  1992 Summer  1992  Summer    Barcelona
# 97711                  Haiti  HAI  1992 Summer  1992  Summer    Barcelona
# 119297                 Niger  NIG  1992 Summer  1992  Summer    Barcelona
# 142611              Canada-1  CAN  1992 Winter  1992  Winter  Albertville
# 143695                 Sudan  SUD  1992 Summer  1992  Summer    Barcelona
# 148865                 Niger  NIG  1992 Summer  1992  Summer    Barcelona
# 161226                Kuwait  KUW  1992 Summer  1992  Summer    Barcelona
# 161890                 Kenya  KEN  1992 Summer  1992  Summer    Barcelona
# 162716                Uganda  UGA  1992 Summer  1992  Summer    Barcelona
# 163135              Ethiopia  ETH  1992 Summer  1992  Summer    Barcelona
# 164820                Rwanda  RWA  1992 Summer  1992  Summer    Barcelona
# 172461                Rwanda  RWA  1992 Summer  1992  Summer    Barcelona
# 174861                 Kenya  KEN  1992 Summer  1992  Summer    Barcelona
# 181423           Philippines  PHI  1992 Summer  1992  Summer    Barcelona
# 181424           Philippines  PHI  1992 Summer  1992  Summer    Barcelona
# 181425           Philippines  PHI  1992 Summer  1992  Summer    Barcelona
# 191526    Dominican Republic  DOM  1992 Summer  1992  Summer    Barcelona
# 215686                Rwanda  RWA  1992 Summer  1992  Summer    Barcelona
# 219027                 Nepal  NEP  1992 Summer  1992  Summer    Barcelona
# 225740              Djibouti  DJI  1992 Summer  1992  Summer    Barcelona
# 225906                Guinea  GUI  1992 Summer  1992  Summer    Barcelona
# 233224          Unified Team  EUN  1992 Summer  1992  Summer    Barcelona
# 235767                 Benin  BEN  1992 Summer  1992  Summer    Barcelona
# 235768                 Benin  BEN  1992 Summer  1992  Summer    Barcelona
# 238015              Ethiopia  ETH  1992 Summer  1992  Summer    Barcelona
#
#                       Sport                                          Event  \
# 73461                Rowing                      Rowing Men's Coxed Eights
# 120234             Swimming          Swimming Women's 800 metres Freestyle
# 120233             Swimming          Swimming Women's 400 metres Freestyle
# 80831            Gymnastics                Gymnastics Women's Balance Beam
# 265499             Swimming  Swimming Women's 200 metres Individual Medley
# 265498             Swimming          Swimming Women's 100 metres Butterfly
# 265497             Swimming          Swimming Women's 400 metres Freestyle
# 102920             Swimming         Swimming Women's 200 metres Backstroke
# 265496             Swimming          Swimming Women's 200 metres Freestyle
# 102919             Swimming         Swimming Women's 100 metres Backstroke
# 41953                Diving                        Diving Women's Platform
# 80830            Gymnastics                 Gymnastics Women's Uneven Bars
# 80829            Gymnastics                 Gymnastics Women's Horse Vault
# 87962        Figure Skating                     Figure Skating Mixed Pairs
# 80827            Gymnastics             Gymnastics Women's Team All-Around
# 73581                Diving                        Diving Women's Platform
# 52617   Rhythmic Gymnastics         Rhythmic Gymnastics Women's Individual
# 80826            Gymnastics       Gymnastics Women's Individual All-Around
# 265494             Swimming           Swimming Women's 50 metres Freestyle
# 265495             Swimming          Swimming Women's 100 metres Freestyle
# 80828            Gymnastics              Gymnastics Women's Floor Exercise
# 47557        Figure Skating                 Figure Skating Women's Singles
# 62787              Swimming          Swimming Women's 100 metres Freestyle
# 194235               Rowing                       Rowing Men's Coxed Fours
# 131670             Swimming          Swimming Women's 400 metres Freestyle
# 131668             Swimming          Swimming Women's 100 metres Freestyle
# 104648             Swimming       Swimming Women's 100 metres Breaststroke
# 104649             Swimming       Swimming Women's 200 metres Breaststroke
# 104650             Swimming   Swimming Women's 4 x 100 metres Medley Relay
# 62788              Swimming          Swimming Women's 200 metres Freestyle
# ...                     ...                                            ...
# 62605          Table Tennis                     Table Tennis Men's Singles
# 78634             Athletics                     Athletics Women's Marathon
# 88366             Athletics                   Athletics Women's 800 metres
# 88367               Cycling            Cycling Men's Road Race, Individual
# 90893               Cycling   Cycling Men's 100 kilometres Team Time Trial
# 91759             Athletics             Athletics Men's 20 kilometres Walk
# 97711                  Judo                   Judo Men's Half-Middleweight
# 119297            Athletics                     Athletics Men's 200 metres
# 142611            Bobsleigh                           Bobsleigh Men's Four
# 143695            Athletics                     Athletics Men's 400 metres
# 148865            Athletics                       Athletics Men's Marathon
# 161226                 Judo                   Judo Men's Extra-Lightweight
# 161890                 Judo                    Judo Men's Half-Lightweight
# 162716         Table Tennis                   Table Tennis Women's Singles
# 163135            Athletics                Athletics Women's 10,000 metres
# 164820              Cycling            Cycling Men's Road Race, Individual
# 172461              Cycling            Cycling Men's Road Race, Individual
# 174861                 Judo                         Judo Men's Heavyweight
# 181423             Swimming           Swimming Men's 100 metres Backstroke
# 181424             Swimming           Swimming Men's 200 metres Backstroke
# 181425             Swimming     Swimming Men's 4 x 100 metres Medley Relay
# 191526             Baseball                        Baseball Men's Baseball
# 215686            Athletics                       Athletics Men's Marathon
# 219027             Shooting          Shooting Women's Air Rifle, 10 metres
# 225740            Athletics                   Athletics Men's 5,000 metres
# 225906            Athletics                   Athletics Women's 200 metres
# 233224               Rowing                      Rowing Men's Coxed Eights
# 235767            Athletics                     Athletics Men's 800 metres
# 235768            Athletics                   Athletics Men's 1,500 metres
# 238015              Cycling   Cycling Men's 100 kilometres Team Time Trial
#
#          Medal Age_category
# 73461      NaN         None
# 120234     NaN         None
# 120233     NaN         None
# 80831      NaN         None
# 265499     NaN         None
# 265498     NaN         None
# 265497     NaN         None
# 102920     NaN         None
# 265496     NaN         None
# 102919     NaN         None
# 41953      NaN         None
# 80830      NaN         None
# 80829      NaN         None
# 87962      NaN         None
# 80827   Silver         None
# 73581     Gold         None
# 52617      NaN         None
# 80826      NaN         None
# 265494     NaN         None
# 265495     NaN         None
# 80828      NaN         None
# 47557      NaN         None
# 62787      NaN         None
# 194235     NaN         None
# 131670     NaN         None
# 131668     NaN         None
# 104648     NaN         None
# 104649    Gold         None
# 104650     NaN         None
# 62788      NaN         None
# ...        ...          ...
# 62605      NaN         None
# 78634      NaN         None
# 88366      NaN         None
# 88367      NaN         None
# 90893      NaN         None
# 91759      NaN         None
# 97711      NaN         None
# 119297     NaN         None
# 142611     NaN         None
# 143695     NaN         None
# 148865     NaN         None
# 161226     NaN         None
# 161890     NaN         None
# 162716     NaN         None
# 163135     NaN         None
# 164820     NaN         None
# 172461     NaN         None
# 174861     NaN         None
# 181423     NaN         None
# 181424     NaN         None
# 181425     NaN         None
# 191526     NaN         None
# 215686     NaN         None
# 219027     NaN         None
# 225740     NaN         None
# 225906     NaN         None
# 233224     NaN         None
# 235767     NaN         None
# 235768     NaN         None
# 238015     NaN         None
#
# [16413 rows x 16 columns]

# %%
data['Age'][(data['Year']==1992) & (data['Sex']=='F')].min()
# Out:
# 12.0

# %% [markdown]
# __2. What was the percentage of male basketball players among all the male participants of the 2012 Olympics? Round the answer to the first decimal.__
#
# *Hint:* here and further if needed drop duplicated sportsmen to count only unique ones.
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 0.2
# - 1.5
# - 2.5 [+]
# - 7.7

# %%
# You code here
#data['Name'][(data['Year']==2012) & (data['Sex']=='M') & (data['Sport']=='Basketball')].drop_duplicates(subset='Name', keep='first')/\
#data[(data['Year']==2012) & (data['Sex']=='M') ].shape[0]
#.drop_duplicates(subset='Name', keep='first')

dropd = data[(data['Year']==2012) & (data['Sex']=='M') &(data['Sport']=='Basketball')].drop_duplicates(subset='Name', keep='first')
dropd.describe()
dropd1 = data[(data['Year']==2012) & (data['Sex']=='M') ].drop_duplicates(subset='Name', keep='first')
dropd1.describe()
round(len(dropd)/len(dropd1)*100, 1)
# Out:
# 2.5

# %% [markdown]
# __3. What are the mean and standard deviation of height for female tennis players who participated in the 2000 Olympics? Round the answer to the first decimal.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 171.8 and 6.5 [+]
# - 179.4 and 10
# - 180.7 and 6.7
# - 182.4 and 9.1

# %%
# You code here

                
            
droped = data[(data['Year']==2000) & (data['Sex']=='F') &(data['Sport']=='Tennis')].drop_duplicates(subset='Name', keep='first')
print(droped['Height'].mean(),\
      droped["Height"].std())
# Out:
# 171.8068181818182 6.563321899569362

# %%
data[(data['Year']==2000) & (data['Sex']=='F') &(data['Sport']=='Tennis')]
data['Height'].mean()
#wrong cos has duplicates
# Out:
# 175.33896987366376

# %% [markdown]
# __4. Find a sportsman who participated in the 2006 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - Judo
# - Bobsleigh
# - Skeleton [+]
# - Boxing

# %%
# You code here
#max_load = data['hours-per-week'].max()
#print("Max time - {0} hours./week.".format(max_load))
#num_workaholics = data[data['hours-per-week'] == max_load].shape[0]
max_kg=data[(data['Year']==2006)]['Weight'].max()
data[(data['Year']==2006) & (data['Weight']==max_kg)]
# Out:
#         ID               Name Sex   Age  Height  Weight     Team  NOC  \
# 8102  4476  Patrick R. Antaki   M  41.0   185.0   127.0  Lebanon  LIB
#
#             Games  Year  Season    City     Sport                    Event  \
# 8102  2006 Winter  2006  Winter  Torino  Skeleton  Skeleton Men's Skeleton
#
#      Medal
# 8102   NaN

# %% [markdown]
# __5. How many times did John Aalberg participate in the Olympics held in different years?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q1-5_fall2019*
#
# - 0
# - 1
# - 2 [+]
# - 3

# %%
# You code here
data[data['Name']=='John Aalberg'].drop_duplicates(subset='Year',keep='first') #.shape[0]
# Out:
#     ID          Name Sex   Age  Height  Weight           Team  NOC  \
# 18   7  John Aalberg   M  31.0   183.0    72.0  United States  USA
# 22   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
#
#           Games  Year  Season         City                 Sport  \
# 18  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 22  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
#
#                                        Event Medal
# 18  Cross Country Skiing Men's 10 kilometres   NaN
# 22  Cross Country Skiing Men's 10 kilometres   NaN

# %% [markdown]
# __6. How many gold medals in tennis did sportspeople from the Switzerland team win at the 2008 Olympics? Count every medal from every sportsperson.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - 0
# - 1
# - 2 [+]
# - 3

# %%
# You code here
data['Medal'][(data['NOC']=='SUI') & (data['Sport']=='Tennis') & (data['Year']==2008) ].value_counts()
# Out:
#             ID                       Name Sex   Age  Height  Weight  \
# 12201     6632           Timea Bacsinszky   F  19.0   170.0    62.0
# 67289    34396              Roger Federer   M  26.0   185.0    80.0
# 67290    34396              Roger Federer   M  26.0   185.0    80.0
# 74580    37884       Emmanuelle Gagliardi   F  32.0   171.0    60.0
# 213720  107328  Patty Schnyder (-Hofmann)   F  29.0   168.0    56.0
# 213721  107328  Patty Schnyder (-Hofmann)   F  29.0   168.0    56.0
# 257671  129042         Stanislas Wawrinka   M  23.0   183.0    79.0
# 257672  129042         Stanislas Wawrinka   M  23.0   183.0    79.0
#
#                Team  NOC        Games  Year  Season     City   Sport  \
# 12201   Switzerland  SUI  2008 Summer  2008  Summer  Beijing  Tennis
# 67289   Switzerland  SUI  2008 Summer  2008  Summer  Beijing  Tennis
# 67290   Switzerland  SUI  2008 Summer  2008  Summer  Beijing  Tennis
# 74580   Switzerland  SUI  2008 Summer  2008  Summer  Beijing  Tennis
# 213720  Switzerland  SUI  2008 Summer  2008  Summer  Beijing  Tennis
# 213721  Switzerland  SUI  2008 Summer  2008  Summer  Beijing  Tennis
# 257671  Switzerland  SUI  2008 Summer  2008  Summer  Beijing  Tennis
# 257672  Switzerland  SUI  2008 Summer  2008  Summer  Beijing  Tennis
#
#                          Event Medal
# 12201   Tennis Women's Singles   NaN
# 67289     Tennis Men's Singles   NaN
# 67290     Tennis Men's Doubles  Gold
# 74580   Tennis Women's Doubles   NaN
# 213720  Tennis Women's Singles   NaN
# 213721  Tennis Women's Doubles   NaN
# 257671    Tennis Men's Singles   NaN
# 257672    Tennis Men's Doubles  Gold

# %% [markdown]
# __7. Is it true that Spain won fewer medals than Italy at the 2016 Olympics? Do not consider NaN values in _Medal_ column.__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - Yes [+] (17 Spain and 28 Italy)
# - No

# %%
# You code here
print(data[(data['Team'].apply(lambda state: state[0:5] == 'Spain')) &  (data['Year']==2016) & (data['Medal']) ].drop_duplicates(subset=['Event','Medal'], keep='first').sort_values(by='Medal').shape[0], 
      data[(data['Team'].apply(lambda state: state[0:5] == 'Italy')) &  (data['Year']==2016) & (data['Medal']) ].drop_duplicates(subset=['Event','Medal'], keep='first').sort_values(by='Medal').shape[0])
# Out:
# 17 28

# %% [markdown]
# __8. What age category did the fewest and the most participants of the 2008 Olympics belong to?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - [45-55] and [25-35) correspondingly [+]
# - [45-55] and [15-25) correspondingly
# - [35-45) and [25-35) correspondingly
# - [45-55] and [35-45) correspondingly

# %%
# You code here
def age_category(age):
    '''
    < 30 -> 1
    >= 30, <55 -> 2
    >= 55 -> 3
    '''
    if 15<=age < 25:
        return '15-25'
    elif 25<=age < 35:
        return '25-35'
    elif 35<=age < 45:
        return '35-45'
    elif 45<=age < 55:
        return '45-55'
    
data['Age_category'] = data['Age'].apply(age_category)
data[(data['Year']==2008)]['Age_category'].describe()
pd.crosstab((data['Year']==2008), data['Age_category'])
# Out:
# Age_category   15-25   25-35  35-45  45-55
# Year
# False         123763  104624  14321   3157
# True            6294    6367    790    116

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (8, 6)
sns.countplot(x='Age_category',  data=data[data['Year']==2008]);
plt.savefig('players.png', dpi=300);

# %% [markdown]
# __9. Is it true that there were Summer Olympics held in Atlanta? Is it true that there were Winter Olympics held in Squaw Valley?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - Yes, Yes [+]
# - Yes, No
# - No, Yes
# - No, No

# %%
# You code here
data[data['City']=='Squaw Valley']
# Out:
#             ID                                       Name Sex   Age  Height  \
# 83          24                           Nils Egil Aaness   M  24.0     NaN
# 84          24                           Nils Egil Aaness   M  24.0     NaN
# 113         40                            Roald Edgar Aas   M  31.0     NaN
# 114         40                            Roald Edgar Aas   M  31.0     NaN
# 115         40                            Roald Edgar Aas   M  31.0     NaN
# 1307       735               Benjamin Maxwell "Ben" Acton   M  32.0     NaN
# 2071      1150                           Sven Ingvar Agge   M  34.0     NaN
# 2856      1586                           Shikashi Akazawa   M  25.0   180.0
# 2909      1621             Charles Arthur "Charlie" Akers   M  20.0   177.0
# 3938      2275                     Toimi Johannes Alatalo   M  30.0   174.0
# 3939      2275                     Toimi Johannes Alatalo   M  30.0   174.0
# 3940      2275                     Toimi Johannes Alatalo   M  30.0   174.0
# 4057      2337                              Bruno Alberti   M  25.0   174.0
# 4058      2337                              Bruno Alberti   M  25.0   174.0
# 4059      2337                              Bruno Alberti   M  25.0   174.0
# 4363      2486         Veniamin Veniaminovich Aleksandrov   M  22.0   180.0
# 5279      2987              Aleksandr Davletovich Almetov   M  20.0   178.0
# 5983      3359                                Paul Ambros   M  25.0   174.0
# 6067      3414                 Ronald William "Ron" Amess   M  22.0     NaN
# 6536      3660                         Osvaldo A. Ancinas   M  25.0     NaN
# 6537      3660                         Osvaldo A. Ancinas   M  25.0     NaN
# 6538      3660                         Osvaldo A. Ancinas   M  25.0     NaN
# 6767      3795         Beverly Marie Anderson (-Brockway)   F  21.0     NaN
# 6768      3795         Beverly Marie Anderson (-Brockway)   F  21.0     NaN
# 6881      3866                       Verne Ralph Anderson   M  22.0     NaN
# 6882      3866                       Verne Ralph Anderson   M  22.0     NaN
# 6883      3866                       Verne Ralph Anderson   M  22.0     NaN
# 6923      3884                      Allan Ejvin Andersson   M  28.0     NaN
# 6924      3885                        ke Anders Andersson   M  23.0   177.0
# 7897      4375                   Nikolay Petrovich Anikin   M  28.0     NaN
# ...        ...                                        ...  ..   ...     ...
# 259093  129707                                Kuno Werner   M  34.0     NaN
# 259094  129707                                Kuno Werner   M  34.0     NaN
# 259095  129707                                Kuno Werner   M  34.0     NaN
# 260492  130359                        Adolf Jakob Wiklund   M  38.0     NaN
# 260665  130439                      Hans Erik Wilhelmsson   M  23.0     NaN
# 261149  130691                 Thomas Mark "Tom" Williams   M  19.0   180.0
# 261497  130844             Joseph Peter "Joe Pete" Wilson   M  24.0     NaN
# 261543  130866                             Mary L. Wilson   F  19.0     NaN
# 262523  131354                              Heinz Wolfram   M  25.0     NaN
# 262524  131354                              Heinz Wolfram   M  25.0     NaN
# 262591  131395           Cecilia Ann Womersley (-Jenkins)   F  16.0     NaN
# 262592  131395           Cecilia Ann Womersley (-Jenkins)   F  16.0     NaN
# 262593  131395           Cecilia Ann Womersley (-Jenkins)   F  16.0     NaN
# 263157  131677                           Bo Sune Wretling   M  21.0     NaN
# 264227  132228               Viktor Prokhorovich Yakushev   M  22.0   171.0
# 264314  132272                           Toshihiko Yamada   M  27.0   165.0
# 265605  132901  Radiya Nikolayevna Yeroshina (-Nurgayeva)   F  29.0     NaN
# 265606  132901  Radiya Nikolayevna Yeroshina (-Nurgayeva)   F  29.0     NaN
# 265709  132949                           Torbjrn Yggeseth   M  25.0     NaN
# 266074  133113                Yevgeny Mikhaylovich Yorkin   M  27.0     NaN
# 266096  133128                              Rikio Yoshida   M  20.0   162.0
# 267657  133907                              Nilo Zandanel   M  22.0   167.0
# 268136  134147                    Lev Sergeyevich Zaytsev   M  22.0   179.0
# 268352  134268                            Kazimierz Zelek   M  22.0   169.0
# 268353  134268                            Kazimierz Zelek   M  22.0   169.0
# 268354  134268                            Kazimierz Zelek   M  22.0   169.0
# 269551  134875         Nina Alekseyevna Zhuk (Bakusheva-)   F  25.0     NaN
# 269552  134876                Stanislav Alekseyevich Zhuk   M  25.0     NaN
# 269864  135022              Josef Egon Norbert Zimmermann   M  27.0     NaN
# 270690  135376                           Ross Barta Zucco   M  25.0     NaN
#
#         Weight            Team  NOC        Games  Year  Season          City  \
# 83         NaN          Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 84         NaN          Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 113        NaN          Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 114        NaN          Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 115        NaN          Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 1307       NaN       Australia  AUS  1960 Winter  1960  Winter  Squaw Valley
# 2071       NaN          Sweden  SWE  1960 Winter  1960  Winter  Squaw Valley
# 2856      77.0           Japan  JPN  1960 Winter  1960  Winter  Squaw Valley
# 2909      73.0   United States  USA  1960 Winter  1960  Winter  Squaw Valley
# 3938      67.0         Finland  FIN  1960 Winter  1960  Winter  Squaw Valley
# 3939      67.0         Finland  FIN  1960 Winter  1960  Winter  Squaw Valley
# 3940      67.0         Finland  FIN  1960 Winter  1960  Winter  Squaw Valley
# 4057      75.0           Italy  ITA  1960 Winter  1960  Winter  Squaw Valley
# 4058      75.0           Italy  ITA  1960 Winter  1960  Winter  Squaw Valley
# 4059      75.0           Italy  ITA  1960 Winter  1960  Winter  Squaw Valley
# 4363      81.0    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# 5279      83.0    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# 5983      76.0         Germany  GER  1960 Winter  1960  Winter  Squaw Valley
# 6067       NaN       Australia  AUS  1960 Winter  1960  Winter  Squaw Valley
# 6536       NaN       Argentina  ARG  1960 Winter  1960  Winter  Squaw Valley
# 6537       NaN       Argentina  ARG  1960 Winter  1960  Winter  Squaw Valley
# 6538       NaN       Argentina  ARG  1960 Winter  1960  Winter  Squaw Valley
# 6767       NaN   United States  USA  1960 Winter  1960  Winter  Squaw Valley
# 6768       NaN   United States  USA  1960 Winter  1960  Winter  Squaw Valley
# 6881       NaN          Canada  CAN  1960 Winter  1960  Winter  Squaw Valley
# 6882       NaN          Canada  CAN  1960 Winter  1960  Winter  Squaw Valley
# 6883       NaN          Canada  CAN  1960 Winter  1960  Winter  Squaw Valley
# 6923       NaN          Sweden  SWE  1960 Winter  1960  Winter  Squaw Valley
# 6924      72.0          Sweden  SWE  1960 Winter  1960  Winter  Squaw Valley
# 7897       NaN    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# ...        ...             ...  ...          ...   ...     ...           ...
# 259093     NaN         Germany  GER  1960 Winter  1960  Winter  Squaw Valley
# 259094     NaN         Germany  GER  1960 Winter  1960  Winter  Squaw Valley
# 259095     NaN         Germany  GER  1960 Winter  1960  Winter  Squaw Valley
# 260492     NaN          Sweden  SWE  1960 Winter  1960  Winter  Squaw Valley
# 260665     NaN          Sweden  SWE  1960 Winter  1960  Winter  Squaw Valley
# 261149    82.0   United States  USA  1960 Winter  1960  Winter  Squaw Valley
# 261497     NaN   United States  USA  1960 Winter  1960  Winter  Squaw Valley
# 261543     NaN       Australia  AUS  1960 Winter  1960  Winter  Squaw Valley
# 262523     NaN         Germany  GER  1960 Winter  1960  Winter  Squaw Valley
# 262524     NaN         Germany  GER  1960 Winter  1960  Winter  Squaw Valley
# 262591     NaN     New Zealand  NZL  1960 Winter  1960  Winter  Squaw Valley
# 262592     NaN     New Zealand  NZL  1960 Winter  1960  Winter  Squaw Valley
# 262593     NaN     New Zealand  NZL  1960 Winter  1960  Winter  Squaw Valley
# 263157     NaN          Sweden  SWE  1960 Winter  1960  Winter  Squaw Valley
# 264227     NaN    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# 264314    58.0           Japan  JPN  1960 Winter  1960  Winter  Squaw Valley
# 265605     NaN    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# 265606     NaN    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# 265709     NaN          Norway  NOR  1960 Winter  1960  Winter  Squaw Valley
# 266074     NaN    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# 266096    57.0           Japan  JPN  1960 Winter  1960  Winter  Squaw Valley
# 267657    63.0           Italy  ITA  1960 Winter  1960  Winter  Squaw Valley
# 268136     NaN    Soviet Union  URS  1960 Winter  1960  Winter  Squaw Valley
# 268352    64.0          Poland  POL  1960 Winter  1960  Winter  Squaw Valley
# 268353    64.0          Poland  POL  1960 Winter  1960  Winter  Squaw Valley
# 268354    64.0          Poland  POL  1960 Winter  1960  Winter  Squaw Valley
# 269551     NaN  Soviet Union-1  URS  1960 Winter  1960  Winter  Squaw Valley
# 269552     NaN  Soviet Union-1  URS  1960 Winter  1960  Winter  Squaw Valley
# 269864     NaN         Austria  AUT  1960 Winter  1960  Winter  Squaw Valley
# 270690     NaN   United States  USA  1960 Winter  1960  Winter  Squaw Valley
#
#                        Sport  \
# 83             Speed Skating
# 84             Speed Skating
# 113            Speed Skating
# 114            Speed Skating
# 115            Speed Skating
# 1307              Ice Hockey
# 2071                Biathlon
# 2856              Ice Hockey
# 2909    Cross Country Skiing
# 3938    Cross Country Skiing
# 3939    Cross Country Skiing
# 3940    Cross Country Skiing
# 4057           Alpine Skiing
# 4058           Alpine Skiing
# 4059           Alpine Skiing
# 4363              Ice Hockey
# 5279              Ice Hockey
# 5983              Ice Hockey
# 6067              Ice Hockey
# 6536           Alpine Skiing
# 6537           Alpine Skiing
# 6538           Alpine Skiing
# 6767           Alpine Skiing
# 6768           Alpine Skiing
# 6881           Alpine Skiing
# 6882           Alpine Skiing
# 6883           Alpine Skiing
# 6923    Cross Country Skiing
# 6924              Ice Hockey
# 7897    Cross Country Skiing
# ...                      ...
# 259093  Cross Country Skiing
# 259094              Biathlon
# 259095  Cross Country Skiing
# 260492              Biathlon
# 260665         Speed Skating
# 261149            Ice Hockey
# 261497  Cross Country Skiing
# 261543        Figure Skating
# 262523         Speed Skating
# 262524         Speed Skating
# 262591         Alpine Skiing
# 262592         Alpine Skiing
# 262593         Alpine Skiing
# 263157            Ice Hockey
# 264227            Ice Hockey
# 264314            Ice Hockey
# 265605  Cross Country Skiing
# 265606  Cross Country Skiing
# 265709           Ski Jumping
# 266074            Ice Hockey
# 266096       Nordic Combined
# 267657           Ski Jumping
# 268136         Speed Skating
# 268352  Cross Country Skiing
# 268353  Cross Country Skiing
# 268354  Cross Country Skiing
# 269551        Figure Skating
# 269552        Figure Skating
# 269864         Alpine Skiing
# 270690         Speed Skating
#
#                                                     Event   Medal Age_category
# 83                         Speed Skating Men's 500 metres     NaN        15-25
# 84                       Speed Skating Men's 1,500 metres     NaN        15-25
# 113                      Speed Skating Men's 1,500 metres    Gold        25-35
# 114                      Speed Skating Men's 5,000 metres     NaN        25-35
# 115                     Speed Skating Men's 10,000 metres     NaN        25-35
# 1307                          Ice Hockey Men's Ice Hockey     NaN        25-35
# 2071                         Biathlon Men's 20 kilometres     NaN        25-35
# 2856                          Ice Hockey Men's Ice Hockey     NaN        25-35
# 2909             Cross Country Skiing Men's 15 kilometres     NaN        15-25
# 3938             Cross Country Skiing Men's 15 kilometres     NaN        25-35
# 3939             Cross Country Skiing Men's 30 kilometres     NaN        25-35
# 3940    Cross Country Skiing Men's 4 x 10 kilometres R...    Gold        25-35
# 4057                         Alpine Skiing Men's Downhill     NaN        25-35
# 4058                     Alpine Skiing Men's Giant Slalom     NaN        25-35
# 4059                           Alpine Skiing Men's Slalom     NaN        25-35
# 4363                          Ice Hockey Men's Ice Hockey  Bronze        15-25
# 5279                          Ice Hockey Men's Ice Hockey  Bronze        15-25
# 5983                          Ice Hockey Men's Ice Hockey     NaN        25-35
# 6067                          Ice Hockey Men's Ice Hockey     NaN        15-25
# 6536                         Alpine Skiing Men's Downhill     NaN        25-35
# 6537                     Alpine Skiing Men's Giant Slalom     NaN        25-35
# 6538                           Alpine Skiing Men's Slalom     NaN        25-35
# 6767                   Alpine Skiing Women's Giant Slalom     NaN        15-25
# 6768                         Alpine Skiing Women's Slalom     NaN        15-25
# 6881                         Alpine Skiing Men's Downhill     NaN        15-25
# 6882                     Alpine Skiing Men's Giant Slalom     NaN        15-25
# 6883                           Alpine Skiing Men's Slalom     NaN        15-25
# 6923             Cross Country Skiing Men's 30 kilometres     NaN        25-35
# 6924                          Ice Hockey Men's Ice Hockey     NaN        15-25
# 7897             Cross Country Skiing Men's 15 kilometres     NaN        25-35
# ...                                                   ...     ...          ...
# 259093           Cross Country Skiing Men's 15 kilometres     NaN        25-35
# 259094                       Biathlon Men's 20 kilometres     NaN        25-35
# 259095  Cross Country Skiing Men's 4 x 10 kilometres R...     NaN        25-35
# 260492                       Biathlon Men's 20 kilometres     NaN        35-45
# 260665                     Speed Skating Men's 500 metres     NaN        15-25
# 261149                        Ice Hockey Men's Ice Hockey    Gold        15-25
# 261497           Cross Country Skiing Men's 30 kilometres     NaN        15-25
# 261543                     Figure Skating Women's Singles     NaN        15-25
# 262523                   Speed Skating Men's 5,000 metres     NaN        25-35
# 262524                  Speed Skating Men's 10,000 metres     NaN        25-35
# 262591                     Alpine Skiing Women's Downhill     NaN        15-25
# 262592                 Alpine Skiing Women's Giant Slalom     NaN        15-25
# 262593                       Alpine Skiing Women's Slalom     NaN        15-25
# 263157                        Ice Hockey Men's Ice Hockey     NaN        15-25
# 264227                        Ice Hockey Men's Ice Hockey  Bronze        15-25
# 264314                        Ice Hockey Men's Ice Hockey     NaN        25-35
# 265605         Cross Country Skiing Women's 10 kilometres  Bronze        25-35
# 265606  Cross Country Skiing Women's 3 x 5 kilometres ...  Silver        25-35
# 265709          Ski Jumping Men's Normal Hill, Individual     NaN        25-35
# 266074                        Ice Hockey Men's Ice Hockey  Bronze        25-35
# 266096                   Nordic Combined Men's Individual     NaN        15-25
# 267657          Ski Jumping Men's Normal Hill, Individual     NaN        15-25
# 268136                   Speed Skating Men's 1,500 metres     NaN        15-25
# 268352           Cross Country Skiing Men's 15 kilometres     NaN        15-25
# 268353           Cross Country Skiing Men's 30 kilometres     NaN        15-25
# 268354  Cross Country Skiing Men's 4 x 10 kilometres R...     NaN        15-25
# 269551                         Figure Skating Mixed Pairs     NaN        25-35
# 269552                         Figure Skating Mixed Pairs     NaN        25-35
# 269864                       Alpine Skiing Men's Downhill     NaN        25-35
# 270690                  Speed Skating Men's 10,000 metres     NaN        25-35
#
# [1116 rows x 16 columns]

# %% [markdown]
# __10. What is the absolute difference between the number of unique sports at the 1986 Olympics and 2002 Olympics?__
#
# *For discussions, please stick to [ODS Slack](https://opendatascience.slack.com/), channel #mlcourse_ai_news, pinned thread #a1_q6-10_fall2019*
#
# - 3
# - 10
# - 15 [+]
# - 27

# %%
# You code here
tt=data[(data['Year']==2002)]
oss=data[(data['Year']==1986)]
len(tt['Sport'].unique())
#print(oss['Sport'].unique())
# Out:
# 15

# %% [markdown]
# That's it! Now go and do 30 push-ups! :)
