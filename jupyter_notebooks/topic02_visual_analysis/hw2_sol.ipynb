# %%
# подгружаем все нужные пакеты
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker
# %matplotlib inline

# настройка внешнего вида графиков в seaborn
sns.set_context(
    "notebook", 
    font_scale = 1.5,       
    rc = { 
        "figure.figsize" : (12, 9), 
        "axes.titlesize" : 18 
    }
)

# %%
train = pd.read_csv('data/mlbootcamp5_train.csv', sep=';',
                    index_col='id')

# %%
print('Размер датасета: ', train.shape)
train.head()
# Out:
# Размер датасета:  (70000, 12)
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>gender</th>
#       <th>height</th>
#       <th>weight</th>
#       <th>ap_hi</th>
#       <th>ap_lo</th>
#       <th>cholesterol</th>
#       <th>gluc</th>
#       <th>smoke</th>
#       <th>alco</th>
#       <th>active</th>
#       <th>cardio</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
train_uniques = pd.melt(frame=train, value_vars=['gender','cholesterol', 
                                                 'gluc', 'smoke', 'alco', 
                                                 'active', 'cardio'])

# %%
train_uniques.tail()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>489995</th>
#       <td>cardio</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>489996</th>
#       <td>cardio</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>489997</th>
#       <td>cardio</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>489998</th>
#       <td>cardio</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>489999</th>
#       <td>cardio</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
train_uniques = pd.DataFrame(train_uniques.groupby(['variable', 
                                                    'value'])['value'].count()) \
    .sort_index(level=[0, 1]) \
    .rename(columns={'value': 'count'}) \
    .reset_index()

# %%
train_uniques
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>value</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>active</td>
#       <td>0</td>
#       <td>13739</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>active</td>
#       <td>1</td>
#       <td>56261</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>alco</td>
#       <td>0</td>
#       <td>66236</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>alco</td>
#       <td>1</td>
#       <td>3764</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>cardio</td>
#       <td>0</td>
#       <td>35021</td>
#     </tr>
# ...

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 9, 6
sns.factorplot(x='variable', y='count', hue='value', 
               data=train_uniques, kind='bar', size=12)

# %%
train_uniques = pd.melt(frame=train, value_vars=['gender','cholesterol', 
                                                 'gluc', 'smoke', 'alco', 
                                                 'active'], 
                        id_vars=['cardio'])

# %%
train_uniques.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cardio</th>
#       <th>variable</th>
#       <th>value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>gender</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>gender</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>gender</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>gender</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>gender</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# ...

# %%
train_uniques = pd.DataFrame(train_uniques.groupby(['variable', 'value', 
                                                    'cardio'])['value'].count()) \
    .sort_index(level=[0, 1]) \
    .rename(columns={'value': 'count'}) \
    .reset_index()

# %%
train_uniques
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>value</th>
#       <th>cardio</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>active</td>
#       <td>0</td>
#       <td>0</td>
#       <td>6378</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>active</td>
#       <td>0</td>
#       <td>1</td>
#       <td>7361</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>active</td>
#       <td>1</td>
#       <td>0</td>
#       <td>28643</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>active</td>
#       <td>1</td>
#       <td>1</td>
#       <td>27618</td>
#     </tr>
# ...

# %%
sns.factorplot(x='variable', y='count', hue='value', 
               col='cardio', data=train_uniques, kind='bar', size=9);

# %%
for c in train.columns:
    n = train[c].nunique()
    print(c)
    
    if n <= 3:
        print(n, sorted(train[c].value_counts().to_dict().items()))
    else:
        print(n)
    print(10 * '-')
# Out:
# age
# 8076
# ----------
# gender
# 2 [(1, 45530), (2, 24470)]
# ----------
# height
# 109
# ----------
# weight
# 287
# ----------
# ap_hi
# 153
# ----------
# ap_lo
# 157
# ----------
# cholesterol
# 3 [(1, 52385), (2, 9549), (3, 8066)]
# ----------
# gluc
# 3 [(1, 59479), (2, 5190), (3, 5331)]
# ----------
# smoke
# 2 [(0, 63831), (1, 6169)]
# ----------
# alco
# 2 [(0, 66236), (1, 3764)]
# ----------
# active
# 2 [(0, 13739), (1, 56261)]
# ----------
# cardio
# 2 [(0, 35021), (1, 34979)]
# ----------

# %%
corr_matrix =train.corr()

# %%
corr_matrix
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>gender</th>
#       <th>height</th>
#       <th>weight</th>
#       <th>ap_hi</th>
#       <th>ap_lo</th>
#       <th>cholesterol</th>
#       <th>gluc</th>
#       <th>smoke</th>
#       <th>alco</th>
#       <th>active</th>
#       <th>cardio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>age</th>
#       <td>1.000000</td>
#       <td>-0.022811</td>
#       <td>-0.081515</td>
#       <td>0.053684</td>
#       <td>0.020764</td>
#       <td>0.017647</td>
#       <td>0.154424</td>
#       <td>0.098703</td>
#       <td>-0.047633</td>
#       <td>-0.029723</td>
#       <td>-0.009927</td>
# ...

# %%
sorted(corr_matrix.gender.values)
# Out:
# [-0.035821412777035128,
#  -0.022810651720418545,
#  -0.020491035166513204,
#  0.0058656692269787782,
#  0.0060053085716197359,
#  0.0081094919131231794,
#  0.015253971163314168,
#  0.15540564008999094,
#  0.17096642854794944,
#  0.33813513635729253,
#  0.49903342844217485,
#  1.0]

# %%
sns.heatmap(corr_matrix);

# %%
sns.violinplot(x='gender', y='height',hue='gender', data=train,scale='count')

# %%
dfm=train[train['gender']==2]['height']
dfw=train[train['gender']==1]['height']

# %%
ax = sns.kdeplot(dfm,c='blue')
ax = sns.kdeplot(dfw,c='red')
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\matplotlib\cbook.py:2649: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))

# %%
corr_spear =train.corr(method='spearman')

# %%
corr_spear
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>gender</th>
#       <th>height</th>
#       <th>weight</th>
#       <th>ap_hi</th>
#       <th>ap_lo</th>
#       <th>cholesterol</th>
#       <th>gluc</th>
#       <th>smoke</th>
#       <th>alco</th>
#       <th>active</th>
#       <th>cardio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>age</th>
#       <td>1.000000</td>
#       <td>-0.020176</td>
#       <td>-0.082292</td>
#       <td>0.061559</td>
#       <td>0.219087</td>
#       <td>0.156700</td>
#       <td>0.140113</td>
#       <td>0.091791</td>
#       <td>-0.047471</td>
#       <td>-0.030078</td>
#       <td>-0.010422</td>
# ...

# %%
sns.heatmap(corr_spear);

# %%
corr_matrix
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>gender</th>
#       <th>height</th>
#       <th>weight</th>
#       <th>ap_hi</th>
#       <th>ap_lo</th>
#       <th>cholesterol</th>
#       <th>gluc</th>
#       <th>smoke</th>
#       <th>alco</th>
#       <th>active</th>
#       <th>cardio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>age</th>
#       <td>1.000000</td>
#       <td>-0.022811</td>
#       <td>-0.081515</td>
#       <td>0.053684</td>
#       <td>0.020764</td>
#       <td>0.017647</td>
#       <td>0.154424</td>
#       <td>0.098703</td>
#       <td>-0.047633</td>
#       <td>-0.029723</td>
#       <td>-0.009927</td>
# ...

# %%
jpl=sns.jointplot(x='ap_hi', y='ap_lo', 
              data=train, kind='scatter')
ax=jpl.ax_joint
ax.set_xscale('log')
ax.set_yscale('log')
# jpl.ax_marg_x.set_xscale('log')
# jpl.ax_marg_y.set_yscale('log')

# %%
train['ap_hilg']=np.log(train['ap_hi'].values)
train['ap_lolg']=np.log(train['ap_lo'].values)
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# C:\ProgramData\Miniconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %%
train1=train['ap_lolg'].replace([np.inf, -np.inf], np.nan)
train2=train['ap_hilg'].replace([np.inf, -np.inf], np.nan)

# %%
# train1=train.dropna()

train1.shape
# Out:
# (70000,)

# %%
max(train2)
# Out:
# 9.6815932206223501

# %%
min(train2)
# Out:
# 0.0

# %%
gr=sns.jointplot(x=train2, y=train1, 
               kind='scatter')

# %%
"""Сетка"""

gr.ax_joint.grid(True) 

"""Преобразуем логарифмические значения на шкалах в реальные"""
gr.ax_joint.yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, pos: str(round(int(np.exp(x))))))
gr.ax_joint.xaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, pos: str(round(int(np.exp(x))))))
# gr.savefig('log.png')
gr.fig

# %%
train['age_years'] = (train['age'] / 365.25).astype(int)

# %%
train.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>gender</th>
#       <th>height</th>
#       <th>weight</th>
#       <th>ap_hi</th>
#       <th>ap_lo</th>
#       <th>cholesterol</th>
#       <th>gluc</th>
#       <th>smoke</th>
#       <th>alco</th>
#       <th>active</th>
#       <th>cardio</th>
#       <th>ap_hilg</th>
#       <th>ap_lolg</th>
#       <th>age_years</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 11, 8
cntpl=sns.countplot(x='age_years',data=train,hue='cardio')

# %%
train['age_years'].describe()
# Out:
# count    70000.000000
# mean        52.803257
# std          6.762462
# min         29.000000
# 25%         48.000000
# 50%         53.000000
# 75%         58.000000
# max         64.000000
# Name: age_years, dtype: float64

# %%
cntpl=sns.countplot(x='age_years',data=train)

# %%
trmol=train[train['age_years']>64]
trmol
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>gender</th>
#       <th>height</th>
#       <th>weight</th>
#       <th>ap_hi</th>
#       <th>ap_lo</th>
#       <th>cholesterol</th>
#       <th>gluc</th>
#       <th>smoke</th>
#       <th>alco</th>
#       <th>active</th>
#       <th>cardio</th>
#       <th>ap_hilg</th>
#       <th>ap_lolg</th>
#       <th>age_years</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...
